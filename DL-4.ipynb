# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import time

# %%
# Load dataset
data = pd.read_csv('GOOGL.csv')

# %%
print(len(data))
# Out:
# 4431

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['Close'], label='Google Stock Price')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.title('Google Stock Price Over Time')
plt.legend()
plt.show()

# %%
# Normalize data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(np.array(data['Close']).reshape(-1, 1))

# %%
# Split data into train and test sets
train_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size:]

# %%
# Function to create dataset with time steps
def create_dataset(data, time_step):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), 0])
        y.append(data[i + time_step, 0])
    return np.array(X), np.array(y)

# %%
# Define time steps and create train and test datasets
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
# Reshape data for LSTM input [samples, time steps, features]
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Build LSTM model
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(time_step, 1)),
    LSTM(50),
    Dense(1)
])
# Out:
# C:\Users\gauri\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Compile model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Measure training time
start_time = time.time()

# %%
# Train model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=64, verbose=1)
# Out:
# Epoch 1/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 12s 126ms/step - loss: 0.0048 - val_loss: 6.8666e-04
# Epoch 2/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - loss: 5.5756e-05 - val_loss: 5.4760e-04
# Epoch 3/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 10s 112ms/step - loss: 3.5998e-05 - val_loss: 6.0021e-04
# Epoch 4/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - loss: 3.9072e-05 - val_loss: 9.1137e-04
# Epoch 5/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - loss: 3.6333e-05 - val_loss: 0.0013
# Epoch 6/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - loss: 3.7741e-05 - val_loss: 0.0010
# Epoch 7/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - loss: 3.5803e-05 - val_loss: 9.9042e-04
# Epoch 8/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 120ms/step - loss: 3.4410e-05 - val_loss: 0.0012
# Epoch 9/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - loss: 3.8300e-05 - val_loss: 0.0015
# Epoch 10/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - loss: 3.2178e-05 - val_loss: 0.0011
# Epoch 11/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - loss: 3.5676e-05 - val_loss: 0.0013
# Epoch 12/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - loss: 3.5576e-05 - val_loss: 0.0014
# Epoch 13/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 122ms/step - loss: 3.6583e-05 - val_loss: 8.7598e-04
# Epoch 14/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - loss: 3.4466e-05 - val_loss: 8.4382e-04
# Epoch 15/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 119ms/step - loss: 3.8721e-05 - val_loss: 0.0011
# Epoch 16/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - loss: 3.2818e-05 - val_loss: 8.6021e-04
# Epoch 17/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - loss: 3.1912e-05 - val_loss: 7.0074e-04
# Epoch 18/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - loss: 3.3604e-05 - val_loss: 6.3015e-04
# Epoch 19/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - loss: 2.8639e-05 - val_loss: 6.4978e-04
# Epoch 20/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 120ms/step - loss: 2.9919e-05 - val_loss: 6.3180e-04
# Epoch 21/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 125ms/step - loss: 3.3725e-05 - val_loss: 6.2680e-04
# Epoch 22/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - loss: 3.2104e-05 - val_loss: 9.3362e-04
# Epoch 23/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - loss: 2.8253e-05 - val_loss: 4.3295e-04
# Epoch 24/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - loss: 3.1045e-05 - val_loss: 7.4051e-04
# Epoch 25/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - loss: 2.7050e-05 - val_loss: 4.8306e-04
# Epoch 26/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 120ms/step - loss: 3.2619e-05 - val_loss: 4.8744e-04
# Epoch 27/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - loss: 3.1709e-05 - val_loss: 0.0010
# Epoch 28/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 120ms/step - loss: 3.0616e-05 - val_loss: 0.0014
# Epoch 29/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - loss: 3.7352e-05 - val_loss: 4.8838e-04
# Epoch 30/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 8s 140ms/step - loss: 2.9742e-05 - val_loss: 7.8920e-04
# Epoch 31/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - loss: 2.8036e-05 - val_loss: 5.1823e-04
# Epoch 32/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - loss: 2.6757e-05 - val_loss: 5.8187e-04
# Epoch 33/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - loss: 2.5551e-05 - val_loss: 6.4652e-04
# Epoch 34/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 120ms/step - loss: 2.4684e-05 - val_loss: 5.1352e-04
# Epoch 35/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 126ms/step - loss: 2.6897e-05 - val_loss: 8.2720e-04
# Epoch 36/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 122ms/step - loss: 3.2294e-05 - val_loss: 4.8174e-04
# Epoch 37/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - loss: 2.2443e-05 - val_loss: 6.0946e-04
# Epoch 38/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - loss: 2.4607e-05 - val_loss: 7.9718e-04
# Epoch 39/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - loss: 2.5675e-05 - val_loss: 3.9355e-04
# Epoch 40/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - loss: 2.1942e-05 - val_loss: 7.0996e-04
# Epoch 41/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 10s 115ms/step - loss: 2.6863e-05 - val_loss: 3.1856e-04
# Epoch 42/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - loss: 2.6695e-05 - val_loss: 4.1554e-04
# Epoch 43/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 124ms/step - loss: 2.0346e-05 - val_loss: 4.8346e-04
# Epoch 44/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 115ms/step - loss: 2.0427e-05 - val_loss: 3.9876e-04
# Epoch 45/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 110ms/step - loss: 2.3352e-05 - val_loss: 3.3363e-04
# Epoch 46/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - loss: 2.1633e-05 - val_loss: 5.4479e-04
# Epoch 47/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 10s 108ms/step - loss: 1.9119e-05 - val_loss: 2.9095e-04
# Epoch 48/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step - loss: 2.1728e-05 - val_loss: 3.9918e-04
# Epoch 49/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - loss: 2.0835e-05 - val_loss: 7.0691e-04
# Epoch 50/50
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 116ms/step - loss: 2.8970e-05 - val_loss: 7.8064e-04

# %%
training_time = time.time() - start_time
print("Training Time:", training_time, "seconds")
# Out:
# Training Time: 364.52413058280945 seconds

# %%
# Evaluate model
train_loss = model.evaluate(X_train, y_train, verbose=0)
test_loss = model.evaluate(X_test, y_test, verbose=0)
print('Train Loss:', train_loss)
print('Test Loss:', test_loss)
# Out:
# Train Loss: 2.0968802346033044e-05
# Test Loss: 0.0007285982137545943

# %%
# Measure prediction time
start_time = time.time()

# %%
# Predictions
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)
# Out:
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step

# %%
prediction_time = time.time() - start_time
print("Prediction Time:", prediction_time, "seconds")
# Out:
# Prediction Time: 5.1296586990356445 seconds

# %%
# Inverse scaling to get original stock prices
train_predictions = scaler.inverse_transform(train_predictions)
y_train = scaler.inverse_transform([y_train])
test_predictions = scaler.inverse_transform(test_predictions)
y_test = scaler.inverse_transform([y_test])

# %%
# Plot predictions
plt.figure(figsize=(10, 6))
plt.plot(data.index[:len(train_predictions)], train_predictions, label='Train Predictions')
#plt.plot(data.index[len(train_predictions)+time_step:len(train_predictions)+time_step+len(test_predictions)], test_predictions, label='Test Predictions')
plt.plot(data.index[:len(y_train.flatten())], y_train.flatten(), label='Actual Train')
#plt.plot(data.index[len(y_train.flatten())+time_step:len(y_train.flatten())+time_step+len(y_test.flatten())], y_test.flatten(), label='Actual Test')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.title('Google Stock Price Prediction')
plt.legend()
plt.show()

# %%
# Plot predictions
plt.figure(figsize=(10, 6))
#plt.plot(data.index[:len(train_predictions)], train_predictions, label='Train Predictions')
plt.plot(data.index[len(train_predictions)+time_step:len(train_predictions)+time_step+len(test_predictions)], test_predictions, label='Test Predictions')
#plt.plot(data.index[:len(y_train.flatten())], y_train.flatten(), label='Actual Train')
plt.plot(data.index[len(y_train.flatten())+time_step:len(y_train.flatten())+time_step+len(y_test.flatten())], y_test.flatten(), label='Actual Test')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.title('Google Stock Price Prediction')
plt.legend()
plt.show()

# %%
# Plot predictions
plt.figure(figsize=(10, 6))
plt.plot(data.index[:len(train_predictions)], train_predictions, label='Train Predictions')
plt.plot(data.index[len(train_predictions)+time_step:len(train_predictions)+time_step+len(test_predictions)], test_predictions, label='Test Predictions')
plt.plot(data.index[:len(y_train.flatten())], y_train.flatten(), label='Actual Train')
plt.plot(data.index[len(y_train.flatten())+time_step:len(y_train.flatten())+time_step+len(y_test.flatten())], y_test.flatten(), label='Actual Test')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.title('Google Stock Price Prediction')
plt.legend()
plt.show()

# %% [markdown]
# This code demonstrates a simple example of how to build an LSTM-based RNN model for time series prediction using the Google stock prices dataset. Here's a brief overview of the steps:
#
# Load and visualize the dataset.
#
# Normalize the data to the range [0, 1].
#
# Split the data into train and test sets.
#
# Create sequences of data with specified time steps.
#
# Build an LSTM model with two LSTM layers and a Dense output layer.
#
# Compile the model with mean squared error loss and Adam optimizer.
#
# Train the model on the train data.
#
# Evaluate the model on both train and test data.
#
# Inverse scale the predictions to get the original stock prices.
#
# Plot the actual vs predicted stock prices for both train and test data.
